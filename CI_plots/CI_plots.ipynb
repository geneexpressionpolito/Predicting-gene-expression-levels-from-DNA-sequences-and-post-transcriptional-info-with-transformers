# %%
import os
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# !pip install import-ipynb
import import_ipynb
# Out:
# Collecting import-ipynb
#   Downloading https://files.pythonhosted.org/packages/63/35/495e0021bfdcc924c7cdec4e9fbb87c88dd03b9b9b22419444dc370c8a45/import-ipynb-0.1.3.tar.gz
# Building wheels for collected packages: import-ipynb
#   Building wheel for import-ipynb (setup.py) ... done
#   Created wheel for import-ipynb: filename=import_ipynb-0.1.3-cp37-none-any.whl size=2976 sha256=b72eff049575e00162d4e12a14c804b6961834f21b38a128e8336c5f6f589e0d
#   Stored in directory: /root/.cache/pip/wheels/b4/7b/e9/a3a6e496115dffdb4e3085d0ae39ffe8a814eacc44bbf494b5
# Successfully built import-ipynb
# Installing collected packages: import-ipynb
# Successfully installed import-ipynb-0.1.3

# %%
# %cd "drive/MyDrive/Bionformatics_Project/Colab"
# Out:
# /content/drive/.shortcut-targets-by-id/1he9S1Es-XalZ9vgCRMbTTNd6cXeRkkFI/Bionformatics_Project/Colab

# %%
from Classes.CI_plotter import CI_plt
# Out:
# importing Jupyter notebook from /content/drive/.shortcut-targets-by-id/1he9S1Es-XalZ9vgCRMbTTNd6cXeRkkFI/Bionformatics_Project/Colab/Classes/CI_plotter.ipynb

# %%
X        = ["Xpresso", "BioLSTM\nDeepLncLoc", "Our_Transformer", "DivideEtimpera", "Transformer\nDeepLncLoc"]  # model names
low      = [0.5593,      0.6029,               0.5998,            0.5804,           0.6080]                  # CI lower bound
mean     = [0.5668,      0.6058,               0.6028,            0.5819,           0.6100]                  # CI mean
upper    = [0.5743,      0.6087,               0.6058,            0.5834,           0.6120]                  # CI upper bound
title    = "Model Comparison Xpresso Dataset"                   # title
xlabel   = "Model"                                              # xlabel
ylabel   = "Test R^2"                                           # ylabel
C        = 0.95                                                 # level of confidence
n        = 10                                                   # number of istances
type1    = "_"                                                  # dash symbol
type2    = "_"
type3    = ""
ylim     = "auto"                                               # limit on y axis
grid     = True                                                 # plot grid if true
loc      = 'upper right'                                        # legend location
size     = (20,9)                                               # plot size
fontsize = 18                                                   # font size
save     = True                                                 # save if true
dir      = "CI_plots/"                                          # directory to save
filename = title                                                # filename

plotter = CI_plt(X, low, mean, upper,  
                     title, xlabel, ylabel, C, n, 
                     type1, type2, type3, ylim, grid, 
                     loc, size, fontsize, save, dir, filename)
plotter.plot()

# %%
X        = ["Xpresso (joined)", "Xpresso+microRNA\n(truncatedSVD100)", "Xpresso+microRNA"]
low      = [0.5401,               0.5468,                                 0.4161]
mean     = [0.5508,               0.5527,                                 0.4267]
upper    = [0.5615,               0.5586,                                 0.4373]
title    = "Model Comparison microRNA Dataset"
xlabel   = "Model"
ylabel   = "Test R^2"
C        = 0.95
n        = 10
type1    = "_"
type2    = "_"
type3    = ""
ylim     = "auto"
grid     = True
loc      = 'upper right'
size     = (20,9)
fontsize = 18
save     = True 
dir      = "CI_plots/"
filename = title                                                # filename

plotter = CI_plt(X, low, mean, upper, 
                     title, xlabel, ylabel, C, n, 
                     type1, type2, type3, ylim, grid, 
                     loc, size, fontsize, save, dir, filename)
plotter.plot()

# %% [markdown]
# ### Presentation plots

# %%
X        = ["Xpresso", "BioLSTM\nDeepLncLoc", "Our_Transformer", "DivideEtImpera", "Transformer\nDeepLncLoc"]  # model names
low      = [0.7422,     0.7528,                 0.7442,             0.7571,            0.7558]                      # CI lower bound
mean     = [0.7448,     0.7552,                 0.7460,             0.7587,            0.7601]                      # CI mean
upper    = [0.7474,     0.7576,                 0.7478,             0.7603,            0.7644]                      # CI upper bound
title    = "Model Comparison Transcription Factor Dataset"      # title
xlabel   = "Model"                                              # xlabel
ylabel   = "Test R^2"                                           # ylabel
C        = 0.95                                                 # level of confidence
n        = 10                                                   # number of istances
type1    = "_"                                                  # dash symbol
type2    = "_"
type3    = ""
ylim     = "auto"                                               # limit on y axis
grid     = True                                                 # plot grid if true
loc      = 'upper right'                                        # legend location
size     = (20,9)                                               # plot size
fontsize = 18                                                   # font size
save     = True                                                 # save if true
dir      = "CI_plots/"                                          # directory to save
filename = title                                                # filename

plotter = CI_plt(X, low, mean, upper,  
                     title, xlabel, ylabel, C, n, 
                     type1, type2, type3, ylim, grid, 
                     loc, size, fontsize, save, dir, filename)
plotter.plot()

# %%
X        = ["Xpresso", "BioLSTM\nDeepLncLoc", "Our_Transformer", "DivideEtImpera", "Transformer\nDeepLncLoc"]  # model names
low      = [0.5256,     0.5738,                  0.5623,             0.5286,            0.5880]                            # CI lower bound
mean     = [0.5306,     0.5795,                  0.5663,             0.5340,            0.5958]                            # CI mean
upper    = [0.5356,     0.5852,                  0.5703,             0.5394,            0.6036]                            # CI upper bound
title    = "Model Comparison only Promoters"                                   # title
xlabel   = "Model"                                              # xlabel
ylabel   = "Test R^2"                                           # ylabel
C        = 0.95                                                 # level of confidence
n        = 10                                                   # number of istances
type1    = "_"                                                  # dash symbol
type2    = "_"
type3    = ""
ylim     = "auto"                                           # limit on y axis
grid     = True                                                 # plot grid if true
loc      = 'upper right'                                         # legend location
size     = (20,9)                                               # plot size
fontsize = 18                                                   # font size
save     = True                                                 # save if true
dir      = "CI_plots/"                                          # directory to save
filename = title                                                # filename

plotter = CI_plt(X, low, mean, upper,  
                     title, xlabel, ylabel, C, n, 
                     type1, type2, type3, ylim, grid, 
                     loc, size, fontsize, save, dir, filename)
plotter.plot()

# %% [markdown]
# ### LAST PLOTS

# %%
X        = ["Xpresso", "BioLSTM\nDeepLncLoc", "Original\nTransformer","Our_Transformer", "DivideEtimpera", "Transformer\nDeepLncLoc"]  # model names
low      = [0.5593,      0.6029,               0.4607,                0.5998,            0.5804,           0.6080]                  # CI lower bound
mean     = [0.5668,      0.6058,               0.4700,                0.6028,            0.5819,           0.6100]                  # CI mean
upper    = [0.5743,      0.6087,               0.4793,                0.6058,            0.5834,           0.6120]                  # CI upper bound
title    = "Model Comparison Xpresso Dataset"                   # title
xlabel   = "Model"                                              # xlabel
ylabel   = "Test R^2"                                           # ylabel
C        = 0.95                                                 # level of confidence
n        = 10                                                   # number of istances
type1    = "_"                                                  # dash symbol
type2    = "_"
type3    = ""
ylim     = "auto"                                               # limit on y axis
grid     = True                                                 # plot grid if true
loc      = 'upper right'                                        # legend location
size     = (20,9)                                               # plot size
fontsize = 18                                                   # font size
save     = False                                                # save if true
dir      = "CI_plots/"                                          # directory to save
filename = "modelcomparison"                                    # filename

plotter = CI_plt(X, low, mean, upper,  
                     title, xlabel, ylabel, C, n, 
                     type1, type2, type3, ylim, grid, 
                     loc, size, fontsize, save, dir, filename)
plotter.plot()

# %%
X        = ["FC_net"]  # model names
low      = [0.662]                      # CI lower bound
mean     = [0.670]                      # CI mean
upper    = [0.677]                      # CI upper bound
title    = "Baseline Transcription Factor Dataset without Sequences and Halflife"      # title
xlabel   = "Model"                                              # xlabel
ylabel   = "Test R^2"                                           # ylabel
C        = 0.95                                                 # level of confidence
n        = 10                                                   # number of istances
type1    = "_"                                                  # dash symbol
type2    = "_"
type3    = ""
ylim     = "auto"                                               # limit on y axis
grid     = True                                                 # plot grid if true
loc      = 'upper right'                                        # legend location
size     = (9,9)                                               # plot size
fontsize = 18                                                   # font size
save     = False                                                # save if true
dir      = "CI_plots/"                                          # directory to save
filename = "modelcomparison"                                    # filename

plotter = CI_plt(X, low, mean, upper,  
                     title, xlabel, ylabel, C, n, 
                     type1, type2, type3, ylim, grid, 
                     loc, size, fontsize, save, dir, filename)
plotter.plot()

# %%
X        = ["FC_net", "Xpresso", "BioLSTM\nDeepLncLoc", "Our_Transformer", "DivideEtImpera", "Transformers\nDeepLncLoc"]  # model names
low      = [0.662,     0.742,     0.751,                 0.744,             0.757,            0.756]                      # CI lower bound
mean     = [0.670,     0.745,     0.754,                 0.746,             0.759,            0.760]                      # CI mean
upper    = [0.677,     0.747,     0.757,                 0.748,             0.760,            0.764]                      # CI upper bound
title    = "Model Comparison Transcription Factor Dataset"      # title
xlabel   = "Model"                                              # xlabel
ylabel   = "Test R^2"                                           # ylabel
C        = 0.95                                                 # level of confidence
n        = 10                                                   # number of istances
type1    = "_"                                                  # dash symbol
type2    = "_"
type3    = ""
ylim     = "auto"                                               # limit on y axis
grid     = True                                                 # plot grid if true
loc      = 'upper right'                                        # legend location
size     = (20,9)                                               # plot size
fontsize = 18                                                   # font size
save     = False                                                # save if true
dir      = "CI_plots/"                                          # directory to save
filename = "modelcomparison"                                    # filename

plotter = CI_plt(X, low, mean, upper,  
                     title, xlabel, ylabel, C, n, 
                     type1, type2, type3, ylim, grid, 
                     loc, size, fontsize, save, dir, filename)
plotter.plot()

# %%
X        = ["FC_net", "Xpresso"]  # model names
low      = [0.6624,     0.7422]                      # CI lower bound
mean     = [0.6695,     0.7448]                      # CI mean
upper    = [0.6766,     0.7474]                      # CI upper bound
title    = "Model Comparison Transcription Factor Dataset"      # title
xlabel   = "Model"                                              # xlabel
ylabel   = "Test R^2"                                           # ylabel
C        = 0.95                                                 # level of confidence
n        = 10                                                   # number of istances
type1    = "_"                                                  # dash symbol
type2    = "_"
type3    = ""
ylim     = "auto"                                               # limit on y axis
grid     = True                                                 # plot grid if true
loc      = 'upper right'                                        # legend location
size     = (14,9)                                               # plot size
fontsize = 18                                                   # font size
save     = False                                                # save if true
dir      = "CI_plots/"                                          # directory to save
filename = "modelcomparison"                                    # filename

plotter = CI_plt(X, low, mean, upper,  
                     title, xlabel, ylabel, C, n, 
                     type1, type2, type3, ylim, grid, 
                     loc, size, fontsize, save, dir, filename)
plotter.plot()
