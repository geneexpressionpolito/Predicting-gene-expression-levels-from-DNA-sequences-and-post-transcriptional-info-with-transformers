# %%
# !git clone https://github.com/geneexpressionpolito/Transformers-for-gene-expression-prediction-from-raw-dna-sequences.git
# !mv ./Transformers-for-gene-expression-prediction-from-raw-dna-sequences/Classes ./
# !pip install import-ipynb
# !gdown --folder 1u34ntvh4dL5Y5_hZSA9EDs5SZ32MPda1
import import_ipynb
import os
# Out:
# Cloning into 'Transformers-for-gene-expression-prediction-from-raw-dna-sequences'...
# remote: Enumerating objects: 637, done.
# remote: Counting objects: 100% (37/37), done.
# remote: Compressing objects: 100% (33/33), done.
# remote: Total 637 (delta 10), reused 13 (delta 4), pack-reused 600
# Receiving objects: 100% (637/637), 294.33 MiB | 28.21 MiB/s, done.
# Resolving deltas: 100% (213/213), done.
# Checking out files: 100% (317/317), done.
# ...
# Retrieving folder list
# Retrieving folder 1LlUXiCjvlkmVD7TVUYThrqYr7Btn9aP2 dataset_aumentati
# Processing file 1p9Buj1hE-qK5ZxrgVGA13ID1uLHXhwDP bestparams.h5
# Processing file 1ues1NsK4S7C9Hfqcx5lrje7OAKnB7dwh test_tf.h5
# Processing file 1IYdEF5gU6XFx3cYxJMbnCeylqby3kOLN train_tf.h5
# Processing file 11bokT2WkSidi2ey8grpMXsP3GtKwnDNF translated_transformers_tf.h5
# Processing file 1ReBoBnHp-5iyKwWAwMTW2gbnjTYD_Eqm validation_tf.h5
# Retrieving folder 1zPvlBc6H48CGtSCNAGN7r1_kH1sDH4uD embedded_data
# ...

# %%
# !mkdir CI_plots

# %%
from Classes.CI_plotter import CI_plt
# Out:
# importing Jupyter notebook from /content/Classes/CI_plotter.ipynb

# %%
X        = ["Xpresso", "BioLSTM\nDeepLncLoc", "DivideEtimpera", "Transformer\nDeepLncLoc"]  # model names
low      = [0.5593,      0.6029,               0.5804,           0.6080]                  # CI lower bound
mean     = [0.5668,      0.6058,               0.5819,           0.6100]                  # CI mean
upper    = [0.5743,      0.6087,               0.5834,           0.6120]                  # CI upper bound
title    = "Model Comparison Xpresso Dataset"                   # title
xlabel   = "Model"                                              # xlabel
ylabel   = "Test R^2"                                           # ylabel
C        = 0.95                                                 # level of confidence
n        = 10                                                   # number of istances
type1    = "_"                                                  # dash symbol
type2    = "_"
type3    = ""
ylim     = "auto"                                               # limit on y axis
grid     = True                                                 # plot grid if true
loc      = 'upper right'                                        # legend location
size     = (20,9)                                               # plot size
fontsize = 18                                                   # font size
save     = True                                                 # save if true
dir      = "CI_plots/"                                          # directory to save
filename = title                                                # filename

plotter = CI_plt(X, low, mean, upper,  
                     title, xlabel, ylabel, C, n, 
                     type1, type2, type3, ylim, grid, 
                     loc, size, fontsize, save, dir, filename)
plotter.plot()

# %%
X        = ["Xpresso (joined)", "Xpresso+microRNA\n(truncatedSVD100)", "Xpresso+microRNA"]
low      = [0.5401,               0.5468,                                 0.4161]
mean     = [0.5508,               0.5527,                                 0.4267]
upper    = [0.5615,               0.5586,                                 0.4373]
title    = "Model Comparison microRNA Dataset"
xlabel   = "Model"
ylabel   = "Test R^2"
C        = 0.95
n        = 10
type1    = "_"
type2    = "_"
type3    = ""
ylim     = "auto"
grid     = True
loc      = 'upper right'
size     = (20,9)
fontsize = 18
save     = True 
dir      = "CI_plots/"
filename = title                                                # filename

plotter = CI_plt(X, low, mean, upper, 
                     title, xlabel, ylabel, C, n, 
                     type1, type2, type3, ylim, grid, 
                     loc, size, fontsize, save, dir, filename)
plotter.plot()

# %% [markdown]
# ### Presentation plots

# %%
X        = ["Xpresso", "BioLSTM\nDeepLncLoc", "DivideEtImpera", "Transformer\nDeepLncLoc"]  # model names
low      = [0.7422,     0.7528,                  0.7571,            0.7558]                      # CI lower bound
mean     = [0.7448,     0.7552,                  0.7587,            0.7601]                      # CI mean
upper    = [0.7474,     0.7576,                  0.7603,            0.7644]                      # CI upper bound
title    = "Model Comparison Transcription Factor Dataset"      # title
xlabel   = "Model"                                              # xlabel
ylabel   = "Test R^2"                                           # ylabel
C        = 0.95                                                 # level of confidence
n        = 10                                                   # number of istances
type1    = "_"                                                  # dash symbol
type2    = "_"
type3    = ""
ylim     = "auto"                                               # limit on y axis
grid     = True                                                 # plot grid if true
loc      = 'upper right'                                        # legend location
size     = (20,9)                                               # plot size
fontsize = 18                                                   # font size
save     = True                                                 # save if true
dir      = "CI_plots/"                                          # directory to save
filename = title                                                # filename

plotter = CI_plt(X, low, mean, upper,  
                     title, xlabel, ylabel, C, n, 
                     type1, type2, type3, ylim, grid, 
                     loc, size, fontsize, save, dir, filename)
plotter.plot()

# %%
X        = ["Xpresso", "BioLSTM\nDeepLncLoc", "DivideEtImpera", "Transformer\nDeepLncLoc"]  # model names
low      = [0.5256,     0.5738,                   0.5286,            0.5880]                            # CI lower bound
mean     = [0.5306,     0.5795,                   0.5340,            0.5958]                            # CI mean
upper    = [0.5356,     0.5852,                   0.5394,            0.6036]                            # CI upper bound
title    = "Model Comparison only Promoters"                # title
xlabel   = "Model"                                              # xlabel
ylabel   = "Test R^2"                                           # ylabel
C        = 0.95                                                 # level of confidence
n        = 10                                                   # number of istances
type1    = "_"                                                  # dash symbol
type2    = "_"
type3    = ""
ylim     = "auto"                                           # limit on y axis
grid     = True                                                 # plot grid if true
loc      = 'upper right'                                         # legend location
size     = (20,9)                                               # plot size
fontsize = 18                                                   # font size
save     = True                                                 # save if true
dir      = "CI_plots/"                                          # directory to save
filename = title                                                # filename

plotter = CI_plt(X, low, mean, upper,  
                     title, xlabel, ylabel, C, n, 
                     type1, type2, type3, ylim, grid, 
                     loc, size, fontsize, save, dir, filename)
plotter.plot()

# %% [markdown]
# ### LAST PLOTS

# %%
X        = ["Xpresso", "BioLSTM\nDeepLncLoc", "Original\nTransformer","DivideEtimpera", "Transformer\nDeepLncLoc"]  # model names
low      = [0.5593,      0.6029,               0.4607,                0.5804,           0.6080]                  # CI lower bound
mean     = [0.5668,      0.6058,               0.4700,                0.5819,           0.6100]                  # CI mean
upper    = [0.5743,      0.6087,               0.4793,                0.5834,           0.6120]                  # CI upper bound
title    = "Model Comparison Xpresso Dataset"                   # title
xlabel   = "Model"                                              # xlabel
ylabel   = "Test R^2"                                           # ylabel
C        = 0.95                                                 # level of confidence
n        = 10                                                   # number of istances
type1    = "_"                                                  # dash symbol
type2    = "_"
type3    = ""
ylim     = "auto"                                               # limit on y axis
grid     = True                                                 # plot grid if true
loc      = 'upper right'                                        # legend location
size     = (20,9)                                               # plot size
fontsize = 18                                                   # font size
save     = False                                                # save if true
dir      = "CI_plots/"                                          # directory to save
filename = "modelcomparison"                                    # filename

plotter = CI_plt(X, low, mean, upper,  
                     title, xlabel, ylabel, C, n, 
                     type1, type2, type3, ylim, grid, 
                     loc, size, fontsize, save, dir, filename)
plotter.plot()

# %%
X        = ["FC_net"]  # model names
low      = [0.662]                      # CI lower bound
mean     = [0.670]                      # CI mean
upper    = [0.677]                      # CI upper bound
title    = "Baseline Transcription Factor Dataset without Sequences and Halflife"      # title
xlabel   = "Model"                                              # xlabel
ylabel   = "Test R^2"                                           # ylabel
C        = 0.95                                                 # level of confidence
n        = 10                                                   # number of istances
type1    = "_"                                                  # dash symbol
type2    = "_"
type3    = ""
ylim     = "auto"                                               # limit on y axis
grid     = True                                                 # plot grid if true
loc      = 'upper right'                                        # legend location
size     = (9,9)                                               # plot size
fontsize = 18                                                   # font size
save     = False                                                # save if true
dir      = "CI_plots/"                                          # directory to save
filename = "modelcomparison"                                    # filename

plotter = CI_plt(X, low, mean, upper,  
                     title, xlabel, ylabel, C, n, 
                     type1, type2, type3, ylim, grid, 
                     loc, size, fontsize, save, dir, filename)
plotter.plot()

# %%
X        = ["FC_net", "Xpresso", "BioLSTM\nDeepLncLoc", "DivideEtImpera", "Transformers\nDeepLncLoc"]  # model names
low      = [0.662,     0.742,     0.751,                 0.757,            0.756]                      # CI lower bound
mean     = [0.670,     0.745,     0.754,                 0.759,            0.760]                      # CI mean
upper    = [0.677,     0.747,     0.757,                 0.760,            0.764]                      # CI upper bound
title    = "Model Comparison Transcription Factor Dataset"      # title
xlabel   = "Model"                                              # xlabel
ylabel   = "Test R^2"                                           # ylabel
C        = 0.95                                                 # level of confidence
n        = 10                                                   # number of istances
type1    = "_"                                                  # dash symbol
type2    = "_"
type3    = ""
ylim     = "auto"                                               # limit on y axis
grid     = True                                                 # plot grid if true
loc      = 'upper right'                                        # legend location
size     = (20,9)                                               # plot size
fontsize = 18                                                   # font size
save     = False                                                # save if true
dir      = "CI_plots/"                                          # directory to save
filename = "modelcomparison"                                    # filename

plotter = CI_plt(X, low, mean, upper,  
                     title, xlabel, ylabel, C, n, 
                     type1, type2, type3, ylim, grid, 
                     loc, size, fontsize, save, dir, filename)
plotter.plot()

# %%
X        = ["FC_net", "Xpresso"]  # model names
low      = [0.6624,     0.7422]                      # CI lower bound
mean     = [0.6695,     0.7448]                      # CI mean
upper    = [0.6766,     0.7474]                      # CI upper bound
title    = "Model Comparison Transcription Factor Dataset"      # title
xlabel   = "Model"                                              # xlabel
ylabel   = "Test R^2"                                           # ylabel
C        = 0.95                                                 # level of confidence
n        = 10                                                   # number of istances
type1    = "_"                                                  # dash symbol
type2    = "_"
type3    = ""
ylim     = "auto"                                               # limit on y axis
grid     = True                                                 # plot grid if true
loc      = 'upper right'                                        # legend location
size     = (14,9)                                               # plot size
fontsize = 18                                                   # font size
save     = False                                                # save if true
dir      = "CI_plots/"                                          # directory to save
filename = "modelcomparison"                                    # filename

plotter = CI_plt(X, low, mean, upper,  
                     title, xlabel, ylabel, C, n, 
                     type1, type2, type3, ylim, grid, 
                     loc, size, fontsize, save, dir, filename)
plotter.plot()
