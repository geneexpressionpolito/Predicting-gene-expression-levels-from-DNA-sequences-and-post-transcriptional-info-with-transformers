# %%
# !git clone https://github.com/geneexpressionpolito/Transformers-for-gene-expression-prediction-from-raw-dna-sequences.git
# !mv ./Transformers-for-gene-expression-prediction-from-raw-dna-sequences/Classes ./
# !pip install import-ipynb
# !gdown --folder 1u34ntvh4dL5Y5_hZSA9EDs5SZ32MPda1
import import_ipynb
import os
# Out:
# Mounted at /content/drive

# %%
from Classes.DataManager import DataManager
from Classes.Transformer import projTransformer
from tensorflow import keras
import tensorflow as tf
import numpy as np

# %load_ext tensorboard
# Out:
# importing Jupyter notebook from /content/drive/.shortcut-targets-by-id/1he9S1Es-XalZ9vgCRMbTTNd6cXeRkkFI/Bionformatics_Project/Colab/Classes/DataManager.ipynb
# importing Jupyter notebook from /content/drive/.shortcut-targets-by-id/1he9S1Es-XalZ9vgCRMbTTNd6cXeRkkFI/Bionformatics_Project/Colab/Classes/Transformer.ipynb
# Populating the interactive namespace from numpy and matplotlib
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard

# %% [markdown]
# data loading takes at most 30s, we can improve it saving the numerical representation of sequences

# %%
print("> Loading DataManager...")
dm = DataManager(transformer=True, remove_indicted=True)

print("> Loading train data...")
X_trainhalflife, X_trainpromoter, y_train, geneName_train = dm.get_train(True, True)

print("> Loading validation data...")
X_validationhalflife, X_validationpromoter, y_validation, geneName_validation, _ = dm.get_validation(True, True)

print("> Loading test data...")
X_testhalflife, X_testpromoter, y_test, geneName_test = dm.get_test(True, True)

print("\n**************\n     DONE\n**************\n")
# Out:
# > Loading DataManager...
# > Loading train data...
# > Loading validation data...
# > Loading test data...
#
# **************
#      DONE
# **************

# %% [markdown]
# Preprocessing-> Padding

# %%
leftpos  = 9_500          #3_000 
rightpos = 20_000         #13_500
maxlen   = rightpos-leftpos
print("maxlen: ",maxlen)
# Out:
# maxlen:  10500

# %%
X_trainpromoter_p      = keras.preprocessing.sequence.pad_sequences(X_trainpromoter,      maxlen=maxlen)
X_validationpromoter_p = keras.preprocessing.sequence.pad_sequences(X_validationpromoter, maxlen=maxlen)
X_testpromoter_p       = keras.preprocessing.sequence.pad_sequences(X_testpromoter,       maxlen=maxlen)

# %%
# # Clear any logs from previous runs
#!rm -rf ./logs/transformer_best_0-001/

model_type="onlyPromo"
logdir = None
loss = "mse"

######################################################################################################################
import tensorflow as tf
tf.keras.backend.clear_session()

resolver = tf.distribute.cluster_resolver.TPUClusterResolver(tpu='grpc://' + os.environ['COLAB_TPU_ADDR'])
tf.config.experimental_connect_to_cluster(resolver)
# This is the TPU initialization code that has to be at the beginning.
tf.tpu.experimental.initialize_tpu_system(resolver)
print("All devices: ", tf.config.list_logical_devices('TPU'))

strategy = tf.distribute.experimental.TPUStrategy(resolver)


with strategy.scope():
    net = projTransformer(checkpoint_dir="embeddingweighted/", model_type=model_type, n_epochs=300, batch_size=256, 
                      learning_rate=1e-3, patience=20, optimizer="SGD", vocab_size=4,
                      lr_reduction_epoch=60, maxlen=maxlen, embed_dim=32, num_heads=4, ff_dim=64, dense=64, 
                      dropout_rate=0.1, logdir=logdir, t_rate=0.1, momentum=0.9, loss=loss)
    
########################################################################################################################
# Out:
# INFO:tensorflow:Initializing the TPU system: grpc://10.76.41.2:8470
# INFO:tensorflow:Initializing the TPU system: grpc://10.76.41.2:8470
# INFO:tensorflow:Clearing out eager caches
# INFO:tensorflow:Clearing out eager caches
# INFO:tensorflow:Finished initializing TPU system.
# INFO:tensorflow:Finished initializing TPU system.
# WARNING:absl:`tf.distribute.experimental.TPUStrategy` is deprecated, please use  the non experimental symbol `tf.distribute.TPUStrategy` instead.
# All devices:  [LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:7', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:6', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:5', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:4', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:3', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:0', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:1', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:2', device_type='TPU')]
# INFO:tensorflow:Found TPU system:
# INFO:tensorflow:Found TPU system:
# INFO:tensorflow:*** Num TPU Cores: 8
# INFO:tensorflow:*** Num TPU Cores: 8
# INFO:tensorflow:*** Num TPU Workers: 1
# INFO:tensorflow:*** Num TPU Workers: 1
# INFO:tensorflow:*** Num TPU Cores Per Worker: 8
# INFO:tensorflow:*** Num TPU Cores Per Worker: 8
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:CPU:0, CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:CPU:0, CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:CPU:0, CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:CPU:0, CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:0, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:0, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:1, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:1, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:2, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:2, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:3, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:3, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:4, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:4, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:5, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:5, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:6, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:6, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:7, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:7, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU_SYSTEM:0, TPU_SYSTEM, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU_SYSTEM:0, TPU_SYSTEM, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:XLA_CPU:0, XLA_CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:XLA_CPU:0, XLA_CPU, 0, 0)
# model built
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 10500)]      0
# __________________________________________________________________________________________________
# token_and_position_embedding (T (None, 10500, 32)    336128      input_1[0][0]
# __________________________________________________________________________________________________
# conv1d (Conv1D)                 (None, 10500, 32)    6176        token_and_position_embedding[0][0
# __________________________________________________________________________________________________
# average_pooling1d (AveragePooli (None, 350, 32)      0           conv1d[0][0]
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, 350, 32)      9248        average_pooling1d[0][0]
# __________________________________________________________________________________________________
# average_pooling1d_1 (AveragePoo (None, 35, 32)       0           conv1d_1[0][0]
# __________________________________________________________________________________________________
# average_pooling1d_2 (AveragePoo (None, 35, 32)       0           token_and_position_embedding[0][0
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 35, 32)       128         average_pooling1d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 35, 32)       128         average_pooling1d_2[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 35, 32)       0           batch_normalization[0][0]
#                                                                  batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# transformer_block (TransformerB (None, 35, 32)       21120       add[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 1120)         0           transformer_block[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 64)           71744       flatten[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 64)           0           dense_2[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 64)           4160        dropout_2[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 64)           0           dense_3[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 1)            65          dropout_3[0][0]
# ==================================================================================================
# Total params: 448,897
# Trainable params: 448,769
# Non-trainable params: 128
# __________________________________________________________________________________________________
# Parameters:
# {'checkpoint_dir': 'embeddingweighted/', 'model_type': 'onlyPromo', 'n_epochs': 300, 'batch_size': 256, 'learning_rate': 0.001, 'momentum': 0.9, 'maxlen': 10500, 'embed_dim': 32, 'num_heads': 4, 'ff_dim': 64, 'vocab_size': 4, 'dense': 64, 'dropout_rate': 0.1, 'lr_reduction_epoch': 60, 't_rate': 0.1, 'patience': 20, 'optimizer': 'SGD', 'warmup_steps': 8000, 'shuffle': True, 'logdir': None, 'loss': 'mse', 'history': '', 'model': <tensorflow.python.keras.engine.functional.Functional object at 0x7f5e34889f50>}

# %%
net.train_model([X_trainpromoter_p], y_train, [X_validationpromoter_p], y_validation, True)
# Out:
# Epoch 1/300
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 64/64 [==============================] - 42s 420ms/step - loss: 0.9361 - val_loss: 1.9574
# Epoch 2/300
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 64/64 [==============================] - 3s 45ms/step - loss: 0.7241 - val_loss: 1.8491
# Epoch 3/300
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 64/64 [==============================] - 3s 45ms/step - loss: 0.6880 - val_loss: 1.6124
# Epoch 4/300
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 64/64 [==============================] - 3s 44ms/step - loss: 0.6694 - val_loss: 1.4502
# Epoch 5/300
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 64/64 [==============================] - 3s 47ms/step - loss: 0.6546 - val_loss: 1.3279
# Epoch 6/300
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 64/64 [==============================] - 3s 45ms/step - loss: 0.6443 - val_loss: 1.1119
# Epoch 7/300
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 64/64 [==============================] - 3s 45ms/step - loss: 0.6360 - val_loss: 0.9776
# Epoch 8/300
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 64/64 [==============================] - 3s 45ms/step - loss: 0.6278 - val_loss: 0.7872
# Epoch 9/300
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 64/64 [==============================] - 3s 45ms/step - loss: 0.6196 - val_loss: 0.7467
# Epoch 10/300
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 64/64 [==============================] - 3s 45ms/step - loss: 0.6098 - val_loss: 0.8070
# Epoch 11/300
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 64/64 [==============================] - 3s 45ms/step - loss: 0.5981 - val_loss: 0.6967
# Epoch 12/300
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 64/64 [==============================] - 3s 45ms/step - loss: 0.5897 - val_loss: 0.6593
# Epoch 13/300
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 64/64 [==============================] - 3s 45ms/step - loss: 0.5793 - val_loss: 0.6469
# Epoch 14/300
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 64/64 [==============================] - 3s 45ms/step - loss: 0.5646 - val_loss: 0.9374
# Epoch 15/300
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 64/64 [==============================] - 3s 45ms/step - loss: 0.5554 - val_loss: 0.9121
# Epoch 16/300
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 64/64 [==============================] - 3s 45ms/step - loss: 0.5440 - val_loss: 0.6344
# Epoch 17/300
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 64/64 [==============================] - 3s 45ms/step - loss: 0.5363 - val_loss: 0.7321
# Epoch 18/300
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 64/64 [==============================] - 3s 45ms/step - loss: 0.5305 - val_loss: 0.5438
# Epoch 19/300
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 64/64 [==============================] - 3s 46ms/step - loss: 0.5216 - val_loss: 0.5977
# Epoch 20/300
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 64/64 [==============================] - 3s 49ms/step - loss: 0.5133 - val_loss: 0.5967
# Epoch 21/300
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 64/64 [==============================] - 3s 45ms/step - loss: 0.5040 - val_loss: 0.6492
# Epoch 22/300
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 64/64 [==============================] - 3s 46ms/step - loss: 0.5007 - val_loss: 0.5180
# Epoch 23/300
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 64/64 [==============================] - 3s 44ms/step - loss: 0.4961 - val_loss: 0.5123
# Epoch 24/300
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 64/64 [==============================] - 3s 45ms/step - loss: 0.4903 - val_loss: 0.5105
# Epoch 25/300
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 64/64 [==============================] - 3s 45ms/step - loss: 0.4830 - val_loss: 0.5337
# Epoch 26/300
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 64/64 [==============================] - 3s 44ms/step - loss: 0.4783 - val_loss: 0.5072
# Epoch 27/300
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 64/64 [==============================] - 3s 45ms/step - loss: 0.4748 - val_loss: 0.5386
# Epoch 28/300
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 64/64 [==============================] - 3s 45ms/step - loss: 0.4734 - val_loss: 0.6039
# Epoch 29/300
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 64/64 [==============================] - 3s 45ms/step - loss: 0.4715 - val_loss: 0.5462
# Epoch 30/300
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 64/64 [==============================] - 3s 45ms/step - loss: 0.4618 - val_loss: 0.5226
# Epoch 31/300
#
# Epoch 00031: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 64/64 [==============================] - 3s 44ms/step - loss: 0.4647 - val_loss: 0.5281
# Epoch 32/300
#
# Epoch 00032: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 64/64 [==============================] - 3s 44ms/step - loss: 0.4612 - val_loss: 0.5099
# Epoch 33/300
#
# Epoch 00033: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 64/64 [==============================] - 3s 45ms/step - loss: 0.4593 - val_loss: 0.6435
# Epoch 34/300
#
# Epoch 00034: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 64/64 [==============================] - 3s 45ms/step - loss: 0.4589 - val_loss: 0.7099
# Epoch 35/300
#
# Epoch 00035: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 64/64 [==============================] - 3s 50ms/step - loss: 0.4559 - val_loss: 0.4911
# Epoch 36/300
#
# Epoch 00036: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 64/64 [==============================] - 3s 46ms/step - loss: 0.4490 - val_loss: 0.5097
# Epoch 37/300
#
# Epoch 00037: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 64/64 [==============================] - 3s 45ms/step - loss: 0.4471 - val_loss: 0.4865
# Epoch 38/300
#
# Epoch 00038: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 64/64 [==============================] - 3s 45ms/step - loss: 0.4400 - val_loss: 0.5051
# Epoch 39/300
#
# Epoch 00039: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 64/64 [==============================] - 3s 45ms/step - loss: 0.4342 - val_loss: 1.0422
# Epoch 40/300
#
# Epoch 00040: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 64/64 [==============================] - 3s 45ms/step - loss: 0.4370 - val_loss: 0.5917
# Epoch 41/300
#
# Epoch 00041: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 64/64 [==============================] - 3s 44ms/step - loss: 0.4387 - val_loss: 0.5323
# Epoch 42/300
#
# Epoch 00042: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 64/64 [==============================] - 3s 45ms/step - loss: 0.4329 - val_loss: 0.4864
# Epoch 43/300
#
# Epoch 00043: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 64/64 [==============================] - 3s 45ms/step - loss: 0.4314 - val_loss: 0.4778
# Epoch 44/300
#
# Epoch 00044: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 64/64 [==============================] - 3s 45ms/step - loss: 0.4276 - val_loss: 0.4985
# Epoch 45/300
#
# Epoch 00045: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 64/64 [==============================] - 3s 46ms/step - loss: 0.4246 - val_loss: 0.4839
# Epoch 46/300
#
# Epoch 00046: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 64/64 [==============================] - 3s 45ms/step - loss: 0.4205 - val_loss: 0.4839
# Epoch 47/300
#
# Epoch 00047: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 64/64 [==============================] - 3s 45ms/step - loss: 0.4234 - val_loss: 0.4918
# Epoch 48/300
#
# Epoch 00048: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 64/64 [==============================] - 3s 45ms/step - loss: 0.4184 - val_loss: 0.5203
# Epoch 49/300
#
# Epoch 00049: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 64/64 [==============================] - 3s 45ms/step - loss: 0.4153 - val_loss: 0.9714
# Epoch 50/300
#
# Epoch 00050: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 64/64 [==============================] - 3s 45ms/step - loss: 0.4149 - val_loss: 0.5472
# Epoch 51/300
#
# Epoch 00051: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 64/64 [==============================] - 3s 45ms/step - loss: 0.4045 - val_loss: 0.6070
# Epoch 52/300
#
# Epoch 00052: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 64/64 [==============================] - 3s 45ms/step - loss: 0.4106 - val_loss: 0.5024
# Epoch 53/300
#
# Epoch 00053: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 64/64 [==============================] - 3s 46ms/step - loss: 0.4059 - val_loss: 0.5106
# Epoch 54/300
#
# Epoch 00054: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 64/64 [==============================] - 3s 46ms/step - loss: 0.4054 - val_loss: 0.8001
# Epoch 55/300
#
# Epoch 00055: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 64/64 [==============================] - 3s 45ms/step - loss: 0.4072 - val_loss: 0.4757
# Epoch 56/300
#
# Epoch 00056: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 64/64 [==============================] - 3s 46ms/step - loss: 0.4006 - val_loss: 0.5055
# Epoch 57/300
#
# Epoch 00057: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 64/64 [==============================] - 3s 45ms/step - loss: 0.4004 - val_loss: 0.4803
# Epoch 58/300
#
# Epoch 00058: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 64/64 [==============================] - 3s 45ms/step - loss: 0.3994 - val_loss: 0.4977
# Epoch 59/300
#
# Epoch 00059: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 64/64 [==============================] - 3s 45ms/step - loss: 0.3933 - val_loss: 0.5397
# Epoch 60/300
#
# Epoch 00060: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 64/64 [==============================] - 3s 46ms/step - loss: 0.3904 - val_loss: 0.4734
# Epoch 61/300
#
# Epoch 00061: LearningRateScheduler reducing learning rate to 0.00010000000474974513.
# 64/64 [==============================] - 3s 46ms/step - loss: 0.3809 - val_loss: 0.5036
# Epoch 62/300
#
# Epoch 00062: LearningRateScheduler reducing learning rate to 0.00010000000474974513.
# 64/64 [==============================] - 3s 46ms/step - loss: 0.3776 - val_loss: 0.4922
# Epoch 63/300
#
# Epoch 00063: LearningRateScheduler reducing learning rate to 0.00010000000474974513.
# 64/64 [==============================] - 3s 46ms/step - loss: 0.3789 - val_loss: 0.4706
# Epoch 64/300
#
# Epoch 00064: LearningRateScheduler reducing learning rate to 0.00010000000474974513.
# 64/64 [==============================] - 3s 46ms/step - loss: 0.3792 - val_loss: 0.4713
# Epoch 65/300
#
# Epoch 00065: LearningRateScheduler reducing learning rate to 0.00010000000474974513.
# 64/64 [==============================] - 3s 46ms/step - loss: 0.3743 - val_loss: 0.4698
# Epoch 66/300
#
# Epoch 00066: LearningRateScheduler reducing learning rate to 0.00010000000474974513.
# 64/64 [==============================] - 3s 45ms/step - loss: 0.3774 - val_loss: 0.4735
# Epoch 67/300
#
# Epoch 00067: LearningRateScheduler reducing learning rate to 0.00010000000474974513.
# 64/64 [==============================] - 3s 45ms/step - loss: 0.3811 - val_loss: 0.4731
# Epoch 68/300
#
# Epoch 00068: LearningRateScheduler reducing learning rate to 0.00010000000474974513.
# 64/64 [==============================] - 3s 45ms/step - loss: 0.3771 - val_loss: 0.4829
# Epoch 69/300
#
# Epoch 00069: LearningRateScheduler reducing learning rate to 0.00010000000474974513.
# 64/64 [==============================] - 3s 46ms/step - loss: 0.3748 - val_loss: 0.4685
# Epoch 70/300
#
# Epoch 00070: LearningRateScheduler reducing learning rate to 0.00010000000474974513.
# 64/64 [==============================] - 3s 46ms/step - loss: 0.3762 - val_loss: 0.4718
# Epoch 71/300
#
# Epoch 00071: LearningRateScheduler reducing learning rate to 0.00010000000474974513.
# 64/64 [==============================] - 3s 46ms/step - loss: 0.3743 - val_loss: 0.4747
# Epoch 72/300
#
# Epoch 00072: LearningRateScheduler reducing learning rate to 0.00010000000474974513.
# 64/64 [==============================] - 3s 45ms/step - loss: 0.3754 - val_loss: 0.4692
# Epoch 73/300
#
# Epoch 00073: LearningRateScheduler reducing learning rate to 0.00010000000474974513.
# 64/64 [==============================] - 3s 45ms/step - loss: 0.3752 - val_loss: 0.4685
# Epoch 74/300
#
# Epoch 00074: LearningRateScheduler reducing learning rate to 0.00010000000474974513.
# 64/64 [==============================] - 3s 46ms/step - loss: 0.3749 - val_loss: 0.4700
# Epoch 75/300
#
# Epoch 00075: LearningRateScheduler reducing learning rate to 0.00010000000474974513.
# 64/64 [==============================] - 3s 45ms/step - loss: 0.3759 - val_loss: 0.4688
# Epoch 76/300
#
# Epoch 00076: LearningRateScheduler reducing learning rate to 0.00010000000474974513.
# 64/64 [==============================] - 3s 45ms/step - loss: 0.3732 - val_loss: 0.4752
# Epoch 77/300
#
# Epoch 00077: LearningRateScheduler reducing learning rate to 0.00010000000474974513.
# 64/64 [==============================] - 3s 45ms/step - loss: 0.3754 - val_loss: 0.4842
# Epoch 78/300
#
# Epoch 00078: LearningRateScheduler reducing learning rate to 0.00010000000474974513.
# 64/64 [==============================] - 3s 45ms/step - loss: 0.3727 - val_loss: 0.4712
# Epoch 79/300
#
# Epoch 00079: LearningRateScheduler reducing learning rate to 0.00010000000474974513.
# 64/64 [==============================] - 3s 46ms/step - loss: 0.3771 - val_loss: 0.4680
# Epoch 80/300
#
# Epoch 00080: LearningRateScheduler reducing learning rate to 0.00010000000474974513.
# 64/64 [==============================] - 3s 46ms/step - loss: 0.3753 - val_loss: 0.4696
# Epoch 81/300
#
# Epoch 00081: LearningRateScheduler reducing learning rate to 0.00010000000474974513.
# 64/64 [==============================] - 3s 46ms/step - loss: 0.3752 - val_loss: 0.4692
# Epoch 82/300
#
# Epoch 00082: LearningRateScheduler reducing learning rate to 0.00010000000474974513.
# 64/64 [==============================] - 3s 45ms/step - loss: 0.3719 - val_loss: 0.4677
# Epoch 83/300
#
# Epoch 00083: LearningRateScheduler reducing learning rate to 0.00010000000474974513.
# 64/64 [==============================] - 3s 45ms/step - loss: 0.3744 - val_loss: 0.4707
# Epoch 84/300
#
# Epoch 00084: LearningRateScheduler reducing learning rate to 0.00010000000474974513.
# 64/64 [==============================] - 3s 45ms/step - loss: 0.3740 - val_loss: 0.4688
# Epoch 85/300
#
# Epoch 00085: LearningRateScheduler reducing learning rate to 0.00010000000474974513.
# 64/64 [==============================] - 3s 45ms/step - loss: 0.3735 - val_loss: 0.4687
# Epoch 86/300
#
# Epoch 00086: LearningRateScheduler reducing learning rate to 0.00010000000474974513.
# 64/64 [==============================] - 3s 45ms/step - loss: 0.3724 - val_loss: 0.4788
# Epoch 87/300
#
# Epoch 00087: LearningRateScheduler reducing learning rate to 0.00010000000474974513.
# 64/64 [==============================] - 3s 45ms/step - loss: 0.3710 - val_loss: 0.4691
# Epoch 88/300
#
# Epoch 00088: LearningRateScheduler reducing learning rate to 0.00010000000474974513.
# 64/64 [==============================] - 3s 45ms/step - loss: 0.3714 - val_loss: 0.4701
# Epoch 89/300
#
# Epoch 00089: LearningRateScheduler reducing learning rate to 0.00010000000474974513.
# 64/64 [==============================] - 3s 46ms/step - loss: 0.3701 - val_loss: 0.4685
# Epoch 90/300
#
# Epoch 00090: LearningRateScheduler reducing learning rate to 0.00010000000474974513.
# 64/64 [==============================] - 3s 45ms/step - loss: 0.3700 - val_loss: 0.4701
# Epoch 91/300
#
# Epoch 00091: LearningRateScheduler reducing learning rate to 0.00010000000474974513.
# 64/64 [==============================] - 3s 45ms/step - loss: 0.3723 - val_loss: 0.4674
# Epoch 92/300
#
# Epoch 00092: LearningRateScheduler reducing learning rate to 0.00010000000474974513.
# 64/64 [==============================] - 3s 45ms/step - loss: 0.3699 - val_loss: 0.4708
# Epoch 93/300
#
# Epoch 00093: LearningRateScheduler reducing learning rate to 0.00010000000474974513.
# 64/64 [==============================] - 3s 45ms/step - loss: 0.3697 - val_loss: 0.4691
# Epoch 94/300
#
# Epoch 00094: LearningRateScheduler reducing learning rate to 0.00010000000474974513.
# 64/64 [==============================] - 3s 46ms/step - loss: 0.3700 - val_loss: 0.4758
# Epoch 95/300
#
# Epoch 00095: LearningRateScheduler reducing learning rate to 0.00010000000474974513.
# 64/64 [==============================] - 3s 45ms/step - loss: 0.3677 - val_loss: 0.4682
# Epoch 96/300
#
# Epoch 00096: LearningRateScheduler reducing learning rate to 0.00010000000474974513.
# 64/64 [==============================] - 3s 46ms/step - loss: 0.3725 - val_loss: 0.4715
# Epoch 97/300
#
# Epoch 00097: LearningRateScheduler reducing learning rate to 0.00010000000474974513.
# 64/64 [==============================] - 3s 45ms/step - loss: 0.3691 - val_loss: 0.4795
# Epoch 98/300
#
# Epoch 00098: LearningRateScheduler reducing learning rate to 0.00010000000474974513.
# 64/64 [==============================] - 3s 45ms/step - loss: 0.3700 - val_loss: 0.4684
# Epoch 99/300
#
# Epoch 00099: LearningRateScheduler reducing learning rate to 0.00010000000474974513.
# 64/64 [==============================] - 3s 45ms/step - loss: 0.3665 - val_loss: 0.4683
# Epoch 100/300
#
# Epoch 00100: LearningRateScheduler reducing learning rate to 0.00010000000474974513.
# 64/64 [==============================] - 3s 45ms/step - loss: 0.3676 - val_loss: 0.4672
# Epoch 101/300
#
# Epoch 00101: LearningRateScheduler reducing learning rate to 0.00010000000474974513.
# 64/64 [==============================] - 3s 45ms/step - loss: 0.3663 - val_loss: 0.4692
# Epoch 102/300
#
# Epoch 00102: LearningRateScheduler reducing learning rate to 0.00010000000474974513.
# 64/64 [==============================] - 3s 45ms/step - loss: 0.3656 - val_loss: 0.4944
# Epoch 103/300
#
# Epoch 00103: LearningRateScheduler reducing learning rate to 0.00010000000474974513.
# 64/64 [==============================] - 3s 46ms/step - loss: 0.3673 - val_loss: 0.4671
# Epoch 104/300
#
# Epoch 00104: LearningRateScheduler reducing learning rate to 0.00010000000474974513.
# 64/64 [==============================] - 3s 45ms/step - loss: 0.3711 - val_loss: 0.4728
# Epoch 105/300
#
# Epoch 00105: LearningRateScheduler reducing learning rate to 0.00010000000474974513.
# 64/64 [==============================] - 3s 45ms/step - loss: 0.3661 - val_loss: 0.4721
# Epoch 106/300
#
# Epoch 00106: LearningRateScheduler reducing learning rate to 0.00010000000474974513.
# 64/64 [==============================] - 3s 46ms/step - loss: 0.3654 - val_loss: 0.4705
# Epoch 107/300
#
# Epoch 00107: LearningRateScheduler reducing learning rate to 0.00010000000474974513.
# 64/64 [==============================] - 3s 45ms/step - loss: 0.3654 - val_loss: 0.4717
# Epoch 108/300
#
# Epoch 00108: LearningRateScheduler reducing learning rate to 0.00010000000474974513.
# 64/64 [==============================] - 3s 45ms/step - loss: 0.3683 - val_loss: 0.4669
# Epoch 109/300
#
# Epoch 00109: LearningRateScheduler reducing learning rate to 0.00010000000474974513.
# 64/64 [==============================] - 3s 50ms/step - loss: 0.3666 - val_loss: 0.4706
# Epoch 110/300
#
# Epoch 00110: LearningRateScheduler reducing learning rate to 0.00010000000474974513.
# 64/64 [==============================] - 3s 45ms/step - loss: 0.3672 - val_loss: 0.4686
# Epoch 111/300
#
# Epoch 00111: LearningRateScheduler reducing learning rate to 0.00010000000474974513.
# 64/64 [==============================] - 3s 46ms/step - loss: 0.3637 - val_loss: 0.4705
# Epoch 112/300
#
# Epoch 00112: LearningRateScheduler reducing learning rate to 0.00010000000474974513.
# 64/64 [==============================] - 3s 45ms/step - loss: 0.3666 - val_loss: 0.4760
# Epoch 113/300
#
# Epoch 00113: LearningRateScheduler reducing learning rate to 0.00010000000474974513.
# 64/64 [==============================] - 3s 45ms/step - loss: 0.3669 - val_loss: 0.4692
# Epoch 114/300
#
# Epoch 00114: LearningRateScheduler reducing learning rate to 0.00010000000474974513.
# 64/64 [==============================] - 3s 45ms/step - loss: 0.3647 - val_loss: 0.4733
# Epoch 115/300
#
# Epoch 00115: LearningRateScheduler reducing learning rate to 0.00010000000474974513.
# 64/64 [==============================] - 3s 45ms/step - loss: 0.3637 - val_loss: 0.4679
# Epoch 116/300
#
# Epoch 00116: LearningRateScheduler reducing learning rate to 0.00010000000474974513.
# 64/64 [==============================] - 3s 46ms/step - loss: 0.3637 - val_loss: 0.4682
# Epoch 117/300
#
# Epoch 00117: LearningRateScheduler reducing learning rate to 0.00010000000474974513.
# 64/64 [==============================] - 3s 46ms/step - loss: 0.3622 - val_loss: 0.4859
# Epoch 118/300
#
# Epoch 00118: LearningRateScheduler reducing learning rate to 0.00010000000474974513.
# 64/64 [==============================] - 3s 45ms/step - loss: 0.3624 - val_loss: 0.4684
# Epoch 119/300
#
# Epoch 00119: LearningRateScheduler reducing learning rate to 0.00010000000474974513.
# 64/64 [==============================] - 3s 45ms/step - loss: 0.3671 - val_loss: 0.4827
# Epoch 120/300
#
# Epoch 00120: LearningRateScheduler reducing learning rate to 0.00010000000474974513.
# 64/64 [==============================] - 3s 45ms/step - loss: 0.3598 - val_loss: 0.4674
# Epoch 121/300
#
# Epoch 00121: LearningRateScheduler reducing learning rate to 0.00010000000474974513.
# 64/64 [==============================] - 3s 45ms/step - loss: 0.3655 - val_loss: 0.4745
# Epoch 122/300
#
# Epoch 00122: LearningRateScheduler reducing learning rate to 0.00010000000474974513.
# 64/64 [==============================] - 3s 45ms/step - loss: 0.3651 - val_loss: 0.4754
# Epoch 123/300
#
# Epoch 00123: LearningRateScheduler reducing learning rate to 0.00010000000474974513.
# 64/64 [==============================] - 3s 45ms/step - loss: 0.3611 - val_loss: 0.4720
# Epoch 124/300
#
# Epoch 00124: LearningRateScheduler reducing learning rate to 0.00010000000474974513.
# 64/64 [==============================] - 3s 46ms/step - loss: 0.3639 - val_loss: 0.4758
# Epoch 125/300
#
# Epoch 00125: LearningRateScheduler reducing learning rate to 0.00010000000474974513.
# 64/64 [==============================] - 3s 45ms/step - loss: 0.3625 - val_loss: 0.4876
# Epoch 126/300
#
# Epoch 00126: LearningRateScheduler reducing learning rate to 0.00010000000474974513.
# 64/64 [==============================] - 3s 45ms/step - loss: 0.3597 - val_loss: 0.4711
# Epoch 127/300
#
# Epoch 00127: LearningRateScheduler reducing learning rate to 0.00010000000474974513.
# 64/64 [==============================] - 3s 46ms/step - loss: 0.3639 - val_loss: 0.4702
# Epoch 128/300
#
# Epoch 00128: LearningRateScheduler reducing learning rate to 0.00010000000474974513.
# 64/64 [==============================] - 3s 45ms/step - loss: 0.3600 - val_loss: 0.4729
# Restoring model weights from the end of the best epoch.
# Epoch 00128: early stopping

# %%
net.evaluate([X_testpromoter_p], y_test)
# Out:
# Test R^2 = 0.564

# %%
net.evaluate_best([X_testpromoter_p], y_test, TPU=True)
# Out:
# Test R^2 = 0.564
# 0.5641884535570604

# %%
net.plot_train()

# %%
net.plot_r2([X_testpromoter_p], y_test, True)
# Out:
# WARNING:matplotlib.legend:No handles with labels found to put in legend.

# %%
net.plot_kde([X_testpromoter_p], y_test, True)
