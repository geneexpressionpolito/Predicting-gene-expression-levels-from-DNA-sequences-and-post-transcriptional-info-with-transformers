# %%
# !git clone https://github.com/geneexpressionpolito/Transformers-for-gene-expression-prediction-from-raw-dna-sequences.git
# !mv ./Transformers-for-gene-expression-prediction-from-raw-dna-sequences/Classes ./
# !pip install import-ipynb
# !gdown --folder 1u34ntvh4dL5Y5_hZSA9EDs5SZ32MPda1
import import_ipynb
import os

# %%
from Classes.DataManager import DataManager
from Classes.CNN1D import projCNN1D
from tensorflow import keras
import numpy as np

# %load_ext tensorboard
# Out:
# importing Jupyter notebook from /content/drive/.shortcut-targets-by-id/1he9S1Es-XalZ9vgCRMbTTNd6cXeRkkFI/Bionformatics_Project/Colab/Classes/DataManager.ipynb
# importing Jupyter notebook from /content/drive/.shortcut-targets-by-id/1he9S1Es-XalZ9vgCRMbTTNd6cXeRkkFI/Bionformatics_Project/Colab/Classes/CNN1D.ipynb
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# data loading takes at most 17s

# %%
dm = DataManager(transformer=False, micro=False)
X_trainhalflife, X_trainpromoter, y_train, _, _                 = dm.get_train(True, False, False)
X_validationhalflife, X_validationpromoter, y_validation, _, _  = dm.get_validation(True, False, False)
X_testhalflife, X_testpromoter, y_test, _, _                    = dm.get_test(True, False, False)

# %% [markdown]
# Preprocessing-> Padding

# %%
leftpos  = 3_000          #3_000 
rightpos = 13_500         #13_500

maxlen   = rightpos-leftpos
print("maxlen: ",maxlen)
# Out:
# maxlen:  10500

# %%
X_trainpromoter_p      = X_trainpromoter[:, leftpos:rightpos]
X_validationpromoter_p = X_validationpromoter[:, leftpos:rightpos]
X_testpromoter_p       = X_testpromoter[:, leftpos:rightpos]

# %%
# # Clear any logs from previous runs
#!rm -rf ./logs/tritacarne_0-006/
# maxlen=2000
model_type="DivideEtImpera"
checkpoint_dir="DivideEtImpera/"
logdir = None#f"{model_type}_0-006"
loss = "mse" # "mae" "mean_squared_logarithmic_error" "mse"

######################################################################################################################
import tensorflow as tf
tf.keras.backend.clear_session()

resolver = tf.distribute.cluster_resolver.TPUClusterResolver(tpu='grpc://' + os.environ['COLAB_TPU_ADDR'])
tf.config.experimental_connect_to_cluster(resolver)
# This is the TPU initialization code that has to be at the beginning.
tf.tpu.experimental.initialize_tpu_system(resolver)
print("All devices: ", tf.config.list_logical_devices('TPU'))

strategy = tf.distribute.experimental.TPUStrategy(resolver)


with strategy.scope():
    net = projCNN1D(checkpoint_dir=checkpoint_dir, model_type=model_type, n_epochs=300, batch_size=256, lr_reduction_epoch=70,
                learning_rate=1e-3, CNN_input=(maxlen, 4), dropout_rate=0.5, logdir=logdir, momentum=0.9, patience=15, opt="SGD", loss=loss)
    
########################################################################################################################
# Out:
# INFO:tensorflow:Initializing the TPU system: grpc://10.25.14.162:8470
# INFO:tensorflow:Initializing the TPU system: grpc://10.25.14.162:8470
# INFO:tensorflow:Clearing out eager caches
# INFO:tensorflow:Clearing out eager caches
# INFO:tensorflow:Finished initializing TPU system.
# INFO:tensorflow:Finished initializing TPU system.
# WARNING:absl:`tf.distribute.experimental.TPUStrategy` is deprecated, please use  the non experimental symbol `tf.distribute.TPUStrategy` instead.
# All devices:  [LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:7', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:6', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:4', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:3', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:5', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:0', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:1', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:2', device_type='TPU')]
# INFO:tensorflow:Found TPU system:
# INFO:tensorflow:Found TPU system:
# INFO:tensorflow:*** Num TPU Cores: 8
# INFO:tensorflow:*** Num TPU Cores: 8
# INFO:tensorflow:*** Num TPU Workers: 1
# INFO:tensorflow:*** Num TPU Workers: 1
# INFO:tensorflow:*** Num TPU Cores Per Worker: 8
# INFO:tensorflow:*** Num TPU Cores Per Worker: 8
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:CPU:0, CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:CPU:0, CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:CPU:0, CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:CPU:0, CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:0, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:0, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:1, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:1, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:2, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:2, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:3, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:3, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:4, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:4, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:5, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:5, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:6, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:6, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:7, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:7, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU_SYSTEM:0, TPU_SYSTEM, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU_SYSTEM:0, TPU_SYSTEM, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:XLA_CPU:0, XLA_CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:XLA_CPU:0, XLA_CPU, 0, 0)
# (None, 2000, 4)
# model built
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 10500, 4)]   0
# __________________________________________________________________________________________________
# tf.__operators__.getitem_1 (Sli (None, 1050, 4)      0           input_1[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_2 (Sli (None, 1050, 4)      0           input_1[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_3 (Sli (None, 1050, 4)      0           input_1[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_4 (Sli (None, 1050, 4)      0           input_1[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_5 (Sli (None, 1050, 4)      0           input_1[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_6 (Sli (None, 1050, 4)      0           input_1[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_7 (Sli (None, 1050, 4)      0           input_1[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_8 (Sli (None, 1050, 4)      0           input_1[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_9 (Sli (None, 1050, 4)      0           input_1[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.getitem_10 (Sl (None, 1050, 4)      0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1d (Conv1D)                 (None, 1050, 128)    1664        tf.__operators__.getitem_1[0][0]
# __________________________________________________________________________________________________
# conv1d_3 (Conv1D)               (None, 1050, 128)    1664        tf.__operators__.getitem_2[0][0]
# __________________________________________________________________________________________________
# conv1d_6 (Conv1D)               (None, 1050, 128)    1664        tf.__operators__.getitem_3[0][0]
# __________________________________________________________________________________________________
# conv1d_9 (Conv1D)               (None, 1050, 128)    1664        tf.__operators__.getitem_4[0][0]
# __________________________________________________________________________________________________
# conv1d_12 (Conv1D)              (None, 1050, 128)    1664        tf.__operators__.getitem_5[0][0]
# __________________________________________________________________________________________________
# conv1d_15 (Conv1D)              (None, 1050, 128)    1664        tf.__operators__.getitem_6[0][0]
# __________________________________________________________________________________________________
# conv1d_18 (Conv1D)              (None, 1050, 128)    1664        tf.__operators__.getitem_7[0][0]
# __________________________________________________________________________________________________
# conv1d_21 (Conv1D)              (None, 1050, 128)    1664        tf.__operators__.getitem_8[0][0]
# __________________________________________________________________________________________________
# conv1d_24 (Conv1D)              (None, 1050, 128)    1664        tf.__operators__.getitem_9[0][0]
# __________________________________________________________________________________________________
# conv1d_27 (Conv1D)              (None, 1050, 128)    1664        tf.__operators__.getitem_10[0][0]
# __________________________________________________________________________________________________
# max_pooling1d (MaxPooling1D)    (None, 210, 128)     0           conv1d[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_2 (MaxPooling1D)  (None, 210, 128)     0           conv1d_3[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_4 (MaxPooling1D)  (None, 210, 128)     0           conv1d_6[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_6 (MaxPooling1D)  (None, 210, 128)     0           conv1d_9[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_8 (MaxPooling1D)  (None, 210, 128)     0           conv1d_12[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_10 (MaxPooling1D) (None, 210, 128)     0           conv1d_15[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_12 (MaxPooling1D) (None, 210, 128)     0           conv1d_18[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_14 (MaxPooling1D) (None, 210, 128)     0           conv1d_21[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_16 (MaxPooling1D) (None, 210, 128)     0           conv1d_24[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_18 (MaxPooling1D) (None, 210, 128)     0           conv1d_27[0][0]
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, 210, 128)     49280       max_pooling1d[0][0]
# __________________________________________________________________________________________________
# conv1d_4 (Conv1D)               (None, 210, 128)     49280       max_pooling1d_2[0][0]
# __________________________________________________________________________________________________
# conv1d_7 (Conv1D)               (None, 210, 128)     49280       max_pooling1d_4[0][0]
# __________________________________________________________________________________________________
# conv1d_10 (Conv1D)              (None, 210, 128)     49280       max_pooling1d_6[0][0]
# __________________________________________________________________________________________________
# conv1d_13 (Conv1D)              (None, 210, 128)     49280       max_pooling1d_8[0][0]
# __________________________________________________________________________________________________
# conv1d_16 (Conv1D)              (None, 210, 128)     49280       max_pooling1d_10[0][0]
# __________________________________________________________________________________________________
# conv1d_19 (Conv1D)              (None, 210, 128)     49280       max_pooling1d_12[0][0]
# __________________________________________________________________________________________________
# conv1d_22 (Conv1D)              (None, 210, 128)     49280       max_pooling1d_14[0][0]
# __________________________________________________________________________________________________
# conv1d_25 (Conv1D)              (None, 210, 128)     49280       max_pooling1d_16[0][0]
# __________________________________________________________________________________________________
# conv1d_28 (Conv1D)              (None, 210, 128)     49280       max_pooling1d_18[0][0]
# __________________________________________________________________________________________________
# conv1d_2 (Conv1D)               (None, 210, 128)     49280       conv1d_1[0][0]
# __________________________________________________________________________________________________
# conv1d_5 (Conv1D)               (None, 210, 128)     49280       conv1d_4[0][0]
# __________________________________________________________________________________________________
# conv1d_8 (Conv1D)               (None, 210, 128)     49280       conv1d_7[0][0]
# __________________________________________________________________________________________________
# conv1d_11 (Conv1D)              (None, 210, 128)     49280       conv1d_10[0][0]
# __________________________________________________________________________________________________
# conv1d_14 (Conv1D)              (None, 210, 128)     49280       conv1d_13[0][0]
# __________________________________________________________________________________________________
# conv1d_17 (Conv1D)              (None, 210, 128)     49280       conv1d_16[0][0]
# __________________________________________________________________________________________________
# conv1d_20 (Conv1D)              (None, 210, 128)     49280       conv1d_19[0][0]
# __________________________________________________________________________________________________
# conv1d_23 (Conv1D)              (None, 210, 128)     49280       conv1d_22[0][0]
# __________________________________________________________________________________________________
# conv1d_26 (Conv1D)              (None, 210, 128)     49280       conv1d_25[0][0]
# __________________________________________________________________________________________________
# conv1d_29 (Conv1D)              (None, 210, 128)     49280       conv1d_28[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_1 (MaxPooling1D)  (None, 42, 128)      0           conv1d_2[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_3 (MaxPooling1D)  (None, 42, 128)      0           conv1d_5[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_5 (MaxPooling1D)  (None, 42, 128)      0           conv1d_8[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_7 (MaxPooling1D)  (None, 42, 128)      0           conv1d_11[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_9 (MaxPooling1D)  (None, 42, 128)      0           conv1d_14[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_11 (MaxPooling1D) (None, 42, 128)      0           conv1d_17[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_13 (MaxPooling1D) (None, 42, 128)      0           conv1d_20[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_15 (MaxPooling1D) (None, 42, 128)      0           conv1d_23[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_17 (MaxPooling1D) (None, 42, 128)      0           conv1d_26[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_19 (MaxPooling1D) (None, 42, 128)      0           conv1d_29[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 420, 128)     0           max_pooling1d_1[0][0]
#                                                                  max_pooling1d_3[0][0]
#                                                                  max_pooling1d_5[0][0]
#                                                                  max_pooling1d_7[0][0]
#                                                                  max_pooling1d_9[0][0]
#                                                                  max_pooling1d_11[0][0]
#                                                                  max_pooling1d_13[0][0]
#                                                                  max_pooling1d_15[0][0]
#                                                                  max_pooling1d_17[0][0]
#                                                                  max_pooling1d_19[0][0]
# __________________________________________________________________________________________________
# conv1d_30 (Conv1D)              (None, 420, 128)     49280       concatenate[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_20 (MaxPooling1D) (None, 84, 128)      0           conv1d_30[0][0]
# __________________________________________________________________________________________________
# conv1d_31 (Conv1D)              (None, 84, 128)      49280       max_pooling1d_20[0][0]
# __________________________________________________________________________________________________
# conv1d_32 (Conv1D)              (None, 84, 128)      49280       conv1d_31[0][0]
# __________________________________________________________________________________________________
# conv1d_33 (Conv1D)              (None, 84, 128)      49280       conv1d_32[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 10752)        0           conv1d_33[0][0]
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, 8)]          0
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 10760)        0           flatten[0][0]
#                                                                  input_2[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 64)           688704      concatenate_1[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 64)           0           dense[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 64)           4160        dropout[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 64)           0           dense_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 1)            65          dropout_1[0][0]
# ==================================================================================================
# Total params: 1,892,289
# Trainable params: 1,892,289
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Parameters:
# {'checkpoint_dir': 'DivideEtImpera/', 'model_type': 'DivideEtImpera', 'n_epochs': 300, 'batch_size': 256, 'learning_rate': 0.001, 'momentum': 0.9, 'CNN_input': (10500, 4), 'miRNA_input': (2064,), 'dropout_rate': 0.5, 'lr_reduction_epoch': 70, 'shuffle': True, 'logdir': 'logs/DivideEtImpera_0-006', 'patience': 15, 'opt': 'SGD', 'loss': 'mse', 'n_components_LSA': 100, 'history': '', 'model': <tensorflow.python.keras.engine.functional.Functional object at 0x7fc51a8a4410>}

# %%
net.train_model([X_trainpromoter_p, X_trainhalflife], y_train, [X_validationpromoter_p, X_validationhalflife], y_validation, TPU=True)
# Out:
# WARNING:tensorflow:`write_grads` will be ignored in TensorFlow 2.0 for the `TensorBoard` Callback.
# WARNING:tensorflow:`write_grads` will be ignored in TensorFlow 2.0 for the `TensorBoard` Callback.
# Epoch 1/300
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 64/64 [==============================] - 18s 114ms/step - loss: 0.9550 - val_loss: 0.9225
# Epoch 2/300
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 64/64 [==============================] - 2s 32ms/step - loss: 0.8648 - val_loss: 0.8586
# Epoch 3/300
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 64/64 [==============================] - 2s 33ms/step - loss: 0.8327 - val_loss: 0.8387
# Epoch 4/300
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 64/64 [==============================] - 2s 33ms/step - loss: 0.8173 - val_loss: 0.8289
# Epoch 5/300
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 64/64 [==============================] - 2s 33ms/step - loss: 0.8032 - val_loss: 0.8118
# Epoch 6/300
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 64/64 [==============================] - 2s 33ms/step - loss: 0.7893 - val_loss: 0.7969
# Epoch 7/300
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 64/64 [==============================] - 2s 33ms/step - loss: 0.7717 - val_loss: 0.7760
# Epoch 8/300
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 64/64 [==============================] - 2s 33ms/step - loss: 0.7455 - val_loss: 0.7412
# Epoch 9/300
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 64/64 [==============================] - 2s 33ms/step - loss: 0.7020 - val_loss: 0.6815
# Epoch 10/300
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 64/64 [==============================] - 2s 33ms/step - loss: 0.6484 - val_loss: 0.6220
# Epoch 11/300
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 64/64 [==============================] - 2s 34ms/step - loss: 0.6086 - val_loss: 0.5780
# Epoch 12/300
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 64/64 [==============================] - 2s 33ms/step - loss: 0.5784 - val_loss: 0.5530
# Epoch 13/300
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 64/64 [==============================] - 2s 34ms/step - loss: 0.5621 - val_loss: 0.5421
# Epoch 14/300
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 64/64 [==============================] - 2s 34ms/step - loss: 0.5429 - val_loss: 0.5255
# Epoch 15/300
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 64/64 [==============================] - 2s 34ms/step - loss: 0.5411 - val_loss: 0.5148
# Epoch 16/300
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 64/64 [==============================] - 2s 34ms/step - loss: 0.5249 - val_loss: 0.5638
# Epoch 17/300
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 64/64 [==============================] - 2s 34ms/step - loss: 0.5197 - val_loss: 0.4985
# Epoch 18/300
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 64/64 [==============================] - 2s 33ms/step - loss: 0.5115 - val_loss: 0.4931
# Epoch 19/300
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 64/64 [==============================] - 2s 33ms/step - loss: 0.5125 - val_loss: 0.5020
# Epoch 20/300
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 64/64 [==============================] - 2s 33ms/step - loss: 0.5056 - val_loss: 0.4881
# Epoch 21/300
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 64/64 [==============================] - 2s 34ms/step - loss: 0.4944 - val_loss: 0.4853
# Epoch 22/300
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 64/64 [==============================] - 2s 34ms/step - loss: 0.4937 - val_loss: 0.4932
# Epoch 23/300
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 64/64 [==============================] - 2s 34ms/step - loss: 0.5000 - val_loss: 0.4788
# Epoch 24/300
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 64/64 [==============================] - 2s 33ms/step - loss: 0.4862 - val_loss: 0.4830
# Epoch 25/300
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 64/64 [==============================] - 2s 34ms/step - loss: 0.4759 - val_loss: 0.4747
# Epoch 26/300
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 64/64 [==============================] - 2s 34ms/step - loss: 0.4717 - val_loss: 0.4682
# Epoch 27/300
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 64/64 [==============================] - 2s 33ms/step - loss: 0.4675 - val_loss: 0.4816
# Epoch 28/300
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 64/64 [==============================] - 2s 34ms/step - loss: 0.4667 - val_loss: 0.5006
# Epoch 29/300
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 64/64 [==============================] - 2s 34ms/step - loss: 0.4747 - val_loss: 0.4586
# Epoch 30/300
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 64/64 [==============================] - 2s 34ms/step - loss: 0.4619 - val_loss: 0.4595
# Epoch 31/300
#
# Epoch 00031: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 64/64 [==============================] - 2s 34ms/step - loss: 0.4596 - val_loss: 0.4595
# Epoch 32/300
#
# Epoch 00032: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 64/64 [==============================] - 2s 33ms/step - loss: 0.4519 - val_loss: 0.4630
# Epoch 33/300
#
# Epoch 00033: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 64/64 [==============================] - 2s 34ms/step - loss: 0.4553 - val_loss: 0.4759
# Epoch 34/300
#
# Epoch 00034: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 64/64 [==============================] - 2s 33ms/step - loss: 0.4636 - val_loss: 0.4678
# Epoch 35/300
#
# Epoch 00035: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 64/64 [==============================] - 2s 34ms/step - loss: 0.4541 - val_loss: 0.4768
# Epoch 36/300
#
# Epoch 00036: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 64/64 [==============================] - 2s 35ms/step - loss: 0.4521 - val_loss: 0.4516
# Epoch 37/300
#
# Epoch 00037: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 64/64 [==============================] - 2s 33ms/step - loss: 0.4464 - val_loss: 0.4721
# Epoch 38/300
#
# Epoch 00038: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 64/64 [==============================] - 2s 35ms/step - loss: 0.4380 - val_loss: 0.4768
# Epoch 39/300
#
# Epoch 00039: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 64/64 [==============================] - 2s 33ms/step - loss: 0.4332 - val_loss: 0.5493
# Epoch 40/300
#
# Epoch 00040: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 64/64 [==============================] - 2s 34ms/step - loss: 0.4490 - val_loss: 0.5246
# Epoch 41/300
#
# Epoch 00041: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 64/64 [==============================] - 2s 34ms/step - loss: 0.4375 - val_loss: 0.6339
# Epoch 42/300
#
# Epoch 00042: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 64/64 [==============================] - 2s 33ms/step - loss: 0.4465 - val_loss: 0.4647
# Epoch 43/300
#
# Epoch 00043: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 64/64 [==============================] - 2s 34ms/step - loss: 0.4306 - val_loss: 0.5160
# Epoch 44/300
#
# Epoch 00044: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 64/64 [==============================] - 2s 33ms/step - loss: 0.4294 - val_loss: 0.4437
# Epoch 45/300
#
# Epoch 00045: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 64/64 [==============================] - 2s 38ms/step - loss: 0.4330 - val_loss: 0.4648
# Epoch 46/300
#
# Epoch 00046: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 64/64 [==============================] - 2s 34ms/step - loss: 0.4181 - val_loss: 0.4915
# Epoch 47/300
#
# Epoch 00047: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 64/64 [==============================] - 2s 33ms/step - loss: 0.4225 - val_loss: 0.4477
# Epoch 48/300
#
# Epoch 00048: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 64/64 [==============================] - 2s 34ms/step - loss: 0.4148 - val_loss: 0.4409
# Epoch 49/300
#
# Epoch 00049: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 64/64 [==============================] - 2s 34ms/step - loss: 0.4187 - val_loss: 0.4439
# Epoch 50/300
#
# Epoch 00050: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 64/64 [==============================] - 2s 34ms/step - loss: 0.4091 - val_loss: 0.4499
# Epoch 51/300
#
# Epoch 00051: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 64/64 [==============================] - 2s 33ms/step - loss: 0.4117 - val_loss: 0.4634
# Epoch 52/300
#
# Epoch 00052: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 64/64 [==============================] - 2s 33ms/step - loss: 0.4226 - val_loss: 0.4430
# Epoch 53/300
#
# Epoch 00053: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 64/64 [==============================] - 2s 34ms/step - loss: 0.4147 - val_loss: 0.4404
# Epoch 54/300
#
# Epoch 00054: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 64/64 [==============================] - 2s 33ms/step - loss: 0.4121 - val_loss: 0.4950
# Epoch 55/300
#
# Epoch 00055: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 64/64 [==============================] - 2s 34ms/step - loss: 0.3996 - val_loss: 0.4407
# Epoch 56/300
#
# Epoch 00056: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 64/64 [==============================] - 2s 33ms/step - loss: 0.4036 - val_loss: 0.4475
# Epoch 57/300
#
# Epoch 00057: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 64/64 [==============================] - 2s 33ms/step - loss: 0.3974 - val_loss: 0.4405
# Epoch 58/300
#
# Epoch 00058: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 64/64 [==============================] - 2s 33ms/step - loss: 0.3890 - val_loss: 0.4606
# Epoch 59/300
#
# Epoch 00059: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 64/64 [==============================] - 2s 33ms/step - loss: 0.3970 - val_loss: 0.4464
# Epoch 60/300
#
# Epoch 00060: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 64/64 [==============================] - 2s 33ms/step - loss: 0.3877 - val_loss: 0.4660
# Epoch 61/300
#
# Epoch 00061: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 64/64 [==============================] - 2s 33ms/step - loss: 0.3960 - val_loss: 0.4463
# Epoch 62/300
#
# Epoch 00062: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 64/64 [==============================] - 2s 33ms/step - loss: 0.3794 - val_loss: 0.4518
# Epoch 63/300
#
# Epoch 00063: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 64/64 [==============================] - 2s 34ms/step - loss: 0.3906 - val_loss: 0.4586
# Epoch 64/300
#
# Epoch 00064: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 64/64 [==============================] - 2s 35ms/step - loss: 0.3873 - val_loss: 0.4461
# Epoch 65/300
#
# Epoch 00065: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 64/64 [==============================] - 2s 34ms/step - loss: 0.3719 - val_loss: 0.4668
# Epoch 66/300
#
# Epoch 00066: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 64/64 [==============================] - 2s 34ms/step - loss: 0.3599 - val_loss: 0.4561
# Epoch 67/300
#
# Epoch 00067: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 64/64 [==============================] - 2s 34ms/step - loss: 0.3649 - val_loss: 0.4361
# Epoch 68/300
#
# Epoch 00068: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 64/64 [==============================] - 2s 34ms/step - loss: 0.3608 - val_loss: 0.4401
# Epoch 69/300
#
# Epoch 00069: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 64/64 [==============================] - 2s 34ms/step - loss: 0.3591 - val_loss: 0.4524
# Epoch 70/300
#
# Epoch 00070: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 64/64 [==============================] - 2s 34ms/step - loss: 0.3713 - val_loss: 0.4900
# Epoch 71/300
#
# Epoch 00071: LearningRateScheduler reducing learning rate to 0.00010000000474974513.
# 64/64 [==============================] - 2s 35ms/step - loss: 0.3749 - val_loss: 0.4344
# Epoch 72/300
#
# Epoch 00072: LearningRateScheduler reducing learning rate to 0.00010000000474974513.
# 64/64 [==============================] - 2s 34ms/step - loss: 0.3330 - val_loss: 0.4355
# Epoch 73/300
#
# Epoch 00073: LearningRateScheduler reducing learning rate to 0.00010000000474974513.
# 64/64 [==============================] - 2s 34ms/step - loss: 0.3299 - val_loss: 0.4383
# Epoch 74/300
#
# Epoch 00074: LearningRateScheduler reducing learning rate to 0.00010000000474974513.
# 64/64 [==============================] - 2s 34ms/step - loss: 0.3299 - val_loss: 0.4387
# Epoch 75/300
#
# Epoch 00075: LearningRateScheduler reducing learning rate to 0.00010000000474974513.
# 64/64 [==============================] - 2s 35ms/step - loss: 0.3258 - val_loss: 0.4399
# Epoch 76/300
#
# Epoch 00076: LearningRateScheduler reducing learning rate to 0.00010000000474974513.
# 64/64 [==============================] - 2s 34ms/step - loss: 0.3250 - val_loss: 0.4398
# Epoch 77/300
#
# Epoch 00077: LearningRateScheduler reducing learning rate to 0.00010000000474974513.
# 64/64 [==============================] - 2s 34ms/step - loss: 0.3243 - val_loss: 0.4394
# Epoch 78/300
#
# Epoch 00078: LearningRateScheduler reducing learning rate to 0.00010000000474974513.
# 64/64 [==============================] - 2s 33ms/step - loss: 0.3248 - val_loss: 0.4399
# Epoch 79/300
#
# Epoch 00079: LearningRateScheduler reducing learning rate to 0.00010000000474974513.
# 64/64 [==============================] - 2s 34ms/step - loss: 0.3228 - val_loss: 0.4395
# Epoch 80/300
#
# Epoch 00080: LearningRateScheduler reducing learning rate to 0.00010000000474974513.
# 64/64 [==============================] - 2s 34ms/step - loss: 0.3226 - val_loss: 0.4418
# Epoch 81/300
#
# Epoch 00081: LearningRateScheduler reducing learning rate to 0.00010000000474974513.
# 64/64 [==============================] - 2s 33ms/step - loss: 0.3212 - val_loss: 0.4404
# Epoch 82/300
#
# Epoch 00082: LearningRateScheduler reducing learning rate to 0.00010000000474974513.
# 64/64 [==============================] - 2s 34ms/step - loss: 0.3191 - val_loss: 0.4393
# Epoch 83/300
#
# Epoch 00083: LearningRateScheduler reducing learning rate to 0.00010000000474974513.
# 64/64 [==============================] - 2s 33ms/step - loss: 0.3189 - val_loss: 0.4402
# Epoch 84/300
#
# Epoch 00084: LearningRateScheduler reducing learning rate to 0.00010000000474974513.
# 64/64 [==============================] - 2s 34ms/step - loss: 0.3210 - val_loss: 0.4415
# Epoch 85/300
#
# Epoch 00085: LearningRateScheduler reducing learning rate to 0.00010000000474974513.
# 64/64 [==============================] - 2s 34ms/step - loss: 0.3200 - val_loss: 0.4638
# Epoch 86/300
#
# Epoch 00086: LearningRateScheduler reducing learning rate to 0.00010000000474974513.
# 64/64 [==============================] - 2s 33ms/step - loss: 0.3173 - val_loss: 0.4411
# Restoring model weights from the end of the best epoch.
# Epoch 00086: early stopping

# %%
net.evaluate([X_testpromoter_p, X_testhalflife], y_test)
# Out:
# Test R^2 = 0.581
# 0.5808624788658986

# %%
net.evaluate_best([X_testpromoter_p, X_testhalflife], y_test, TPU=True)
# Out:
# Test R^2 = 0.581
# 0.5808624788658986

# %%
# net.plot_train()

# %%
net.plot_r2([X_testpromoter_p, X_testhalflife], y_test, True)
# Out:
# WARNING:matplotlib.legend:No handles with labels found to put in legend.

# %%
net.plot_kde([X_testpromoter_p, X_testhalflife], y_test, True)

# %%
net.plot_kde([X_trainpromoter_p, X_trainhalflife], y_train, True)

# %%
net.plot_kde([X_validationpromoter_p, X_validationhalflife], y_validation, True)
